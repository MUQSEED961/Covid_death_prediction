# %% [markdown]
# <a href="https://colab.research.google.com/github/MUQSEED961/Covid_death_prediction/blob/main/covid_death_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
covid=pd.read_csv('/content/us-counties.csv')

# %%
covid.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
covid.dtypes
# Out:
# date       object
# county     object
# state      object
# fips      float64
# cases       int64
# deaths    float64
# dtype: object

# %%
covid['date']=pd.to_datetime(covid['date'])#to change object to datetime

# %%
covid.tail()
# Out:
#               date      county    state     fips  cases  deaths
# 2502827 2022-05-13  Sweetwater  Wyoming  56037.0  11088   126.0
# 2502828 2022-05-13       Teton  Wyoming  56039.0  10074    16.0
# 2502829 2022-05-13       Uinta  Wyoming  56041.0   5643    39.0
# 2502830 2022-05-13    Washakie  Wyoming  56043.0   2358    44.0
# 2502831 2022-05-13      Weston  Wyoming  56045.0   1588    18.0

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2502832 entries, 0 to 2502831
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   county  object
#  2   state   object
#  3   fips    float64
#  4   cases   int64
#  5   deaths  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 114.6+ MB

# %%
covid.shape
# Out:
# (2502832, 6)

# %%
covid.isnull().sum()
# Out:
# date          0
# county        0
# state         0
# fips      23678
# cases         0
# deaths    57605
# dtype: int64

# %%
covid['fips'].mean()
# Out:
# np.float64(31399.58357286397)

# %%
covid['fips']=covid['fips'].fillna(31237.004460099553)

# %%
covid['cases'].mean()
# Out:
# np.float64(10033.804996899513)

# %%
covid['cases']=covid['cases'].fillna(390.0442975483221)

# %%
covid['deaths'].mean()
# Out:
# np.float64(161.61002270954802)

# %%
covid['deaths']=covid['deaths'].fillna(22.220847090536882)

# %%
covid.head()
# Out:
#         date     county       state     fips  cases  deaths
# 0 2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1 2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2 2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3 2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4 2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
x=covid.drop(['fips','county','state','deaths'],axis=1)
x['date'] = x['date'].astype('int64') // 10**9 # Convert 'date' to Unix timestamp in seconds
y=covid['deaths']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=45)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score,root_mean_squared_error

# %%
print(r2_score(y_pred,y_test))
# Out:
# 0.7358118368507585

# %%
print(root_mean_squared_error(y_pred,y_test))
# Out:
# 371.93338588893465

# %% [markdown]
# MLP start from here

# %%
from sklearn.preprocessing import StandardScaler

# %%
stand=StandardScaler()

# %%
x_covid = stand.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_covid,y,test_size=0.2,random_state=45)
y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

# %%
import tensorflow as tf

# %%
model1=tf.keras.models.Sequential()

# %%
model1
# Out:
# <Sequential name=sequential_1, built=False>

# %%
#layer1
model1.add(tf.keras.layers.Dense(units=10,activation='relu'))

# %%
#layer2
model1.add(tf.keras.layers.Dense(units=10,activation='relu'))

# %%
#output
model1.add(tf.keras.layers.Dense(units=1))

# %%
#compile
model1.compile(optimizer='adam',loss='mean_squared_error',metrics=['mean_absolute_error'])

# %%
model1.fit(x_train,y_train,epochs=1,batch_size=45)
# Out:
# 44495/44495 ━━━━━━━━━━━━━━━━━━━━ 98s 2ms/step - loss: 124255.3906 - mean_absolute_error: 67.1554

# %%
predictions = model1.predict(x_test)
y_pred1 = predictions
# Out:
# 15643/15643 ━━━━━━━━━━━━━━━━━━━━ 16s 1ms/step

# %%
y_test
# Out:
# array([[233.],
#        [170.],
#        [ 93.],
#        ...,
#        [  0.],
#        [  4.],
#        [ 55.]])

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import r2_score, root_mean_squared_error

print('R2 Score:', r2_score(y_test, y_pred1))
print('Root Mean Squared Error:', root_mean_squared_error(y_test, y_pred1))
# Out:
# R2 Score: 0.8077541811090249
# Root Mean Squared Error: 360.5812048951854
